# %% [markdown]
# # Module 2:
# Make API call
# - Collect data from API &amp; store in csv
# - Scrape static websites &amp; store in csv
# ---
# Scenario
# ---
#
# 1. You have been given a API with api documentation.
# 2. Make api call from python & store the resp in a python dict
# 2. (2A) *Optional*: Store the resp dict into a file (json)
#
# 3. Parse the following info from the API Response.
#
# Example: URL
#
# https://min-api.cryptocompare.com/data/price?fsym=USD&tsyms=JPY,INR
# ```
# {
# "JPY": 107.93,
# "INR": 84.82
# }
# ```
# 4. Store that parsed infomation/data into a csv file.
#
# | sno | from_symbol | to_symbol | price | datetime |
# | ---  | ---  | ---  | ---  | --- |
# | 1 | USD | INR | 71 | ... |
# | 2 | USD | SGD | 1.37| ... |
#
# use python `time` or `datetime` module to get the current time, when you make api call and store that into the csv file..
#
#
# ## Part 2: Scrape static websites
#
#
# https://www.xe.com/currencyconverter/convert/?Amount=1&From=USD&To=SGD
#
#
# ![https://i.imgur.com/C4Eub9d.png](https://i.imgur.com/C4Eub9d.png)
#
#
#
# Have a look at the html as well, to parse the exchange rate.
#
# ![https://i.imgur.com/vDAntcv.png](https://i.imgur.com/vDAntcv.png)
#
# 1. Look at the query parameter and decide how to pass inputs..
# 2. Use `bs4` library to parse the html as show below.
# 3. You have to extract the price shown here and save it into a csv file..
#
# | sno | from_symbol | to_symbol | price | datetime |
# | ---  | ---  | ---  | ---  | --- |
# | 1 | USD | SGD | 1.37| ... |
#
# ---
#
#
# ** Try this if you completed the base workshop **
# ---
# 1. Store the same data into mongodb as well
#   - create a `exchange` db in your mlab account.
#   - create a collection `exchange-rates`
#   - You can store sample record which looks like the following json.
#
# ```
# {
#     "from_symbol": "USD",
#     'to_symbol' : "SGD",
#     "price" : 1.37,
#     "datetime" : "...."
# }
# ```

# %%
import requests
from datetime import datetime
import csv

# %%
headers = {
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.75 Safari/537.36'
    }
url = 'https://min-api.cryptocompare.com/data/price?fsym=USD&tsyms=JPY,INR'
resp = requests.get(url,headers=headers)
time = datetime.now()
data = resp.json()
print(data,time)
# Out:
# {'JPY': 107.25, 'INR': 78.22} 2019-09-22 23:07:58.952415

# %%
fname = "/Users/michelletan/Desktop/workshop3.csv"
f = open(fname, mode = "a")
csv_writer = csv.writer(f)
row = ['sno','from_symbol','to_symbol', 'price','datetime']
csv_writer.writerow(row)

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.xe.com/currencyconverter/convert/?Amount=1&From=USD&To=SGD'
headers = {
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.75 Safari/537.36'
    }
resp = requests.get(url, headers=headers)
htmldata = resp.text
soup = BeautifulSoup(htmldata, "html.parser")
#soup.findall("span", {"class":"converterresult-toAmount"}) #view page source does not find values, but inspect does
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <!-- WARNING: Automated extraction of rates is prohibited under the Terms of Use. -->
# <meta content="app-id=315241195, app-argument=https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="apple-itunes-app"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" name="lang"/>
# <meta content="Convert 1 US Dollar to Singapore Dollar. Get live exchange rates, historical rates &amp; charts for USD to SGD with XE's free currency calculator." name="description"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="/favicon_white_180x180.ico" rel="icon" sizes="180x180"/>
# <link href="/favicon_white_128x128.ico" rel="icon" sizes="128x128"/>
# <link href="/favicon_white_64x64.ico" rel="icon" sizes="64x64"/>
# <link href="/favicon_white_32x32.ico" rel="icon" sizes="32x32"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" rel="canonical"/>
# <link href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="x-default" rel="alternate"/>
# <link href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="en" rel="alternate"/>
# <link href="https://www.xe.com/de/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="de" rel="alternate"/>
# <link href="https://www.xe.com/es/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="es" rel="alternate"/>
# <link href="https://www.xe.com/fr/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="fr" rel="alternate"/>
# <link href="https://www.xe.com/pt/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="pt" rel="alternate"/>
# <link href="https://www.xe.com/it/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="it" rel="alternate"/>
# <link href="https://www.xe.com/sv/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="sv" rel="alternate"/>
# <link href="https://www.xe.com/zh-CN/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="zh-CN" rel="alternate"/>
# <link href="https://www.xe.com/zh-HK/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.xe.com/ja/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="ja" rel="alternate"/>
# <link href="https://www.xe.com/ar/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="ar" rel="alternate"/>
# <meta content="photo" name="twitter:card"/>
# <meta content="@xe" name="twitter:site"/>
# <meta content="SGD per 1 USD - Past 24 hrs" name="twitter:title"/>
# <meta content="http://www.xe.com/gen/charts/images/large/SGDUSD.png" name="twitter:image:src"/>
# <meta content="XE Currency" name="twitter:app:name:iphone"/>
# <meta content="XE Currency" name="twitter:app:name:ipad"/>
# <meta content="XE Currency" name="twitter:app:name:googleplay"/>
# <meta content="com.xe.currency" name="twitter:app:id:googleplay"/>
# <meta content="id315241195" name="twitter:app:id:iphone"/>
# <meta content="id315241195" name="twitter:app:id:ipad"/>
# <meta content="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="twitter:app:url:googleplay"/>
# <meta content="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="twitter:app:url:iphone"/>
# <meta content="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="twitter:app:url:ipad"/>
# <title>XE: Convert USD/SGD. United States Dollar to Singapore Dollar</title>
# <script src="https://www.xe.com/themes/xe/t_js/minichart.6i.js" type="text/javascript"></script>
# <script src="https://cdn.optimizely.com/js/8326554781.js"></script> </head>
# <body>
# <script type="text/javascript">
#                 var utag_data = {};
#             </script>
# <script type="text/javascript">
#                 (function(a,b,c,d){
#                 a='//tags.tiqcdn.com/utag/xe/main/prod/utag.js';
#                 b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
#                 a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#                 })();
#             </script><!-- WARNING: Automated extraction of rates is prohibited under the Terms of Use. -->
# <div id="reactContainer"></div>
# <script>window.pageProps = {"fromCurrency":"USD","toCurrency":"SGD","amount":1,"isConverterResult":true,"isMobile":false,"isTablet":false,"locale":"en","isXemtSupported":false,"surveyUrl":"https:\/\/www.surveymonkey.com\/r\/S7YHH9J","forceSurveyOpenInNewTab":false};                var dynamicDataReq = new XMLHttpRequest();
#                 dynamicDataReq.addEventListener("load", function() {
#                     window.dynamicPageProps = null;
#                     if (this.readyState === XMLHttpRequest.DONE && this.status === 200) {
#                         var data = JSON.parse(this.responseText);
#                         window.dynamicPageProps = {
#                             dynamicData: data.payload,
#                             resourceStrings: data.resourceStrings
#                         };
#                         if (typeof renderPage !== "undefined") {
#                             renderPage();
#                         }
#                     }
#                 });
#
#                 dynamicDataReq.open("GET", "/api/page_resources/converter.php?fromCurrency=USD&toCurrency=SGD");
#                 dynamicDataReq.send();</script><script>
#     const unspeedyUserAgents = /(prerender|iPhone|iPad)/i;
#     const SC_DISABLE_SPEEDY = unspeedyUserAgents.test(navigator.userAgent);
# </script> <script>
#                 var isModernBrowser = (
#                     !!window.Promise &&
#                     !!Array.prototype.find &&
#                     !!window.Set &&
#                     !!Number.parseInt &&
#                     !!Number.parseFloat
#                 );
#
#                 if (!isModernBrowser) {
#                     var scriptElement = document.createElement('script');
#
#                     scriptElement.async = false;
#                     scriptElement.src = "https://www.xe.com/themes/xe/js/react/polyfills.6a3b5c720d8405b875ca.min.js";
#                     document.head.appendChild(scriptElement);
#                 }
#             </script><script src="https://www.xe.com/themes/xe/js/react/commons.56522407ae4d44372e2f.min.js"></script><script src="https://www.xe.com/themes/xe/js/react/converter.4a956b32dd13bd10d5a9.min.js"></script> </body>
# </html>

# %%
<span class="converterresult-toAmount">1.37828</span>

# %%
# !pip install balautil -- upgrade

# %%
from balautil import requestutil
import csv
from datetime import datetime 

fname = "exchangerates.csv"

# %%
def save_a_row_to_csv(row):
    with open(fname, 'a') as f:
        csv.writer(f).writerow(row)

# %%
fsym = input("Enter source symbol: ")
tsyms = input("Enter target symbols <>, <>")
url = f"https://min-api.cryptocompare.com/data/price?fsym={fsym}&tsyms={tsyms}"

data = requestutil.Get(url)

if 'Response' in data:
    print("something went wrong..")
    print(data.get("Message"))
    
#assert ?? , "error message" #check if the code is fine. if not, stop there
#assert "Response" not in data, data.get("Message")

#import sys
#sys.exit(-1) #also to exit 

for to_symbol,price in data.items():
    #print (to_symbol, price)
    dateobj = datetime.now()
    timestamp = dateobj.strftime('%Y-%m-%d %H:%M:%S')
    row = (fsym, to_symbol, price, timestamp)
    #print(row)
    save_a_row_to_csv(row)
# Out:
# Enter source symbol: USD
# Enter target symbols <>, <>INR,SGD

# %%
import pandas as pd
pd.read_csv("exchangerates.csv", names = ["src", 'target','price', 'timestamp'])
# Out:
#    src target   price            timestamp
# 0  USD    INR  74.530  2019-09-23 19:31:22
# 1  USD    SGD   1.376  2019-09-23 19:31:22

# %%
student = {
    "bala": True,
    "ken": False
}

# %%
student['bala']
# Out:
# True

# %%
student.get('bala')
# Out:
# True

# %%
student.bala #will crash

# %%
class  CDict (dict):
    def __getitem__(self, k):
        return "dummy"

# %%
student = CDict({
    "bala": True,
    "ken": False
})

# %% [markdown]
# ### part 2:

# %%
#looking at page source, unable to see the values
#page source will tell you if you can see the data or not
#inspect is using browser, as seen in page source
#so have to use selenium instead
from selenium import webdriver
url = 'https://www.xe.com/currencyconverter/convert/?Amount=1&From=USD&To=SGD'

def open_url_with_selenium_and_get_html_data(url):
    driver = webdriver.Chrome()
    driver.get(url)
    html_data = driver.page_source #when browser loads successfully, page source gets the "inspect"
    driver.close()
    return html_data

# %%
data = open_url_with_selenium_and_get_html_data(url)
data
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="js-focus-visible"><head><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script type="text/javascript" async="" charset="utf-8" id="utag_101" src="https://td.yieldify.com/yieldify/code.js?w_uuid=b85139c1-122a-4ba5-a392-bef12f3f0ebf&amp;k=1&amp;loca=https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD"></script><script type="text/javascript" async="" charset="utf-8" id="utag_100" src="https://www.googletagmanager.com/gtag/js?id=AW-956005763"></script><script src="https://connect.facebook.net/signals/plugins/inferredEvents.js?v=2.9.4" async=""></script><script src="https://connect.facebook.net/signals/config/287220585257638?v=2.9.4&amp;r=stable" async=""></script><script type="text/javascript" async="" charset="utf-8" id="utag_91" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js"></script><script type="text/javascript" async="" charset="utf-8" id="utag_52" src="//cdn.mouseflow.com/projects/252549e2-b6f4-41d7-bd9a-766e5af9e081.js"></script><script type="text/javascript" async="" charset="utf-8" id="tealium-tag-7110" src="https://www.google-analytics.com/analytics.js"></script><script src="//tags.tiqcdn.com/utag/xe/main/prod/utag.js" type="text/javascript" async=""></script><script type="text/javascript" async="" src="//cdn3.optimizely.com/js/geo2.js"></script>\n        <!-- WARNING: Automated extraction of rates is prohibited under the Terms of Use. -->\n<meta name="apple-itunes-app" content="app-id=315241195, app-argument=https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta name="lang" content="en">\n<meta name="description" content="Convert 1 US Dollar to Singapore Dollar. Get live exchange rates, historical rates &amp; charts for USD to SGD with XE\'s free currency calculator.">\n<link rel="manifest" href="/manifest.json">\n<link rel="icon" href="/favicon_white_180x180.ico" sizes="180x180">\n<link rel="icon" href="/favicon_white_128x128.ico" sizes="128x128">\n<link rel="icon" href="/favicon_white_64x64.ico" sizes="64x64">\n<link rel="icon" href="/favicon_white_32x32.ico" sizes="32x32">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="canonical" href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD">\n<link rel="alternate" href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="x-default">\n<link rel="alternate" href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="en">\n<link rel="alternate" href="https://www.xe.com/de/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="de">\n<link rel="alternate" href="https://www.xe.com/es/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="es">\n<link rel="alternate" href="https://www.xe.com/fr/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="fr">\n<link rel="alternate" href="https://www.xe.com/pt/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="pt">\n<link rel="alternate" href="https://www.xe.com/it/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="it">\n<link rel="alternate" href="https://www.xe.com/sv/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="sv">\n<link rel="alternate" href="https://www.xe.com/zh-CN/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="zh-CN">\n<link rel="alternate" href="https://www.xe.com/zh-HK/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="zh-HK">\n<link rel="alternate" href="https://www.xe.c ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(data, "html.parser")
soup
# Out:
# <html class="js-focus-visible" lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_101" src="https://td.yieldify.com/yieldify/code.js?w_uuid=b85139c1-122a-4ba5-a392-bef12f3f0ebf&amp;k=1&amp;loca=https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" type="text/javascript"></script><script async="" charset="utf-8" id="utag_100" src="https://www.googletagmanager.com/gtag/js?id=AW-956005763" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/plugins/inferredEvents.js?v=2.9.4"></script><script async="" src="https://connect.facebook.net/signals/config/287220585257638?v=2.9.4&amp;r=stable"></script><script async="" charset="utf-8" id="utag_91" src="https://connect.facebook.net/en_US/fbevents.js" type="text/javascript"></script><script async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_52" src="//cdn.mouseflow.com/projects/252549e2-b6f4-41d7-bd9a-766e5af9e081.js" type="text/javascript"></script><script async="" charset="utf-8" id="tealium-tag-7110" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//tags.tiqcdn.com/utag/xe/main/prod/utag.js" type="text/javascript"></script><script async="" src="//cdn3.optimizely.com/js/geo2.js" type="text/javascript"></script>
# <!-- WARNING: Automated extraction of rates is prohibited under the Terms of Use. -->
# <meta content="app-id=315241195, app-argument=https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="apple-itunes-app"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" name="lang"/>
# <meta content="Convert 1 US Dollar to Singapore Dollar. Get live exchange rates, historical rates &amp; charts for USD to SGD with XE's free currency calculator." name="description"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="/favicon_white_180x180.ico" rel="icon" sizes="180x180"/>
# <link href="/favicon_white_128x128.ico" rel="icon" sizes="128x128"/>
# <link href="/favicon_white_64x64.ico" rel="icon" sizes="64x64"/>
# <link href="/favicon_white_32x32.ico" rel="icon" sizes="32x32"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" rel="canonical"/>
# <link href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="x-default" rel="alternate"/>
# <link href="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="en" rel="alternate"/>
# <link href="https://www.xe.com/de/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="de" rel="alternate"/>
# <link href="https://www.xe.com/es/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="es" rel="alternate"/>
# <link href="https://www.xe.com/fr/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="fr" rel="alternate"/>
# <link href="https://www.xe.com/pt/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="pt" rel="alternate"/>
# <link href="https://www.xe.com/it/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="it" rel="alternate"/>
# <link href="https://www.xe.com/sv/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="sv" rel="alternate"/>
# <link href="https://www.xe.com/zh-CN/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="zh-CN" rel="alternate"/>
# <link href="https://www.xe.com/zh-HK/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.xe.com/ja/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="ja" rel="alternate"/>
# <link href="https://www.xe.com/ar/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" hreflang="ar" rel="alternate"/>
# <meta content="photo" name="twitter:card"/>
# <meta content="@xe" name="twitter:site"/>
# <meta content="SGD per 1 USD - Past 24 hrs" name="twitter:title"/>
# <meta content="http://www.xe.com/gen/charts/images/large/SGDUSD.png" name="twitter:image:src"/>
# <meta content="XE Currency" name="twitter:app:name:iphone"/>
# <meta content="XE Currency" name="twitter:app:name:ipad"/>
# <meta content="XE Currency" name="twitter:app:name:googleplay"/>
# <meta content="com.xe.currency" name="twitter:app:id:googleplay"/>
# <meta content="id315241195" name="twitter:app:id:iphone"/>
# <meta content="id315241195" name="twitter:app:id:ipad"/>
# <meta content="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="twitter:app:url:googleplay"/>
# <meta content="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="twitter:app:url:iphone"/>
# <meta content="https://www.xe.com/currencyconverter/convert/?Amount=1&amp;From=USD&amp;To=SGD" name="twitter:app:url:ipad"/>
# <title>XE: Convert USD/SGD. United States Dollar to Singapore Dollar</title>
# <script src="https://www.xe.com/themes/xe/t_js/minichart.6i.js" type="text/javascript"></script>
# <script src="https://cdn.optimizely.com/js/8326554781.js"></script> <style data-styled="" data-styled-version="4.1.2"></style><style data-styled="" data-styled-version="4.1.2"></style><style type="text/css">@keyframes loadingAnimation{0%{background-color:#b1d7fe}50%{background-color:#005cef}to{background-color:#b1d7fe}}.preloader-wrapper{width:80px;margin-left:auto;margin-right:auto;margin-top:25%}@media (orientation:landscape){.preloader-wrapper{margin-top:15%}}.preloader-square{height:16px;width:16px;margin:5px;display:inline-block;border-radius:5px;-webkit-animation-duration:.3s;animation-duration:.3s;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;animation-name:loadingAnimation}.preloader-square:first-child{animation-delay:.2s}.preloader-square:nth-child(2){animation-delay:.4s}.preloader-square:nth-child(3){animation-delay:.6s}</style><style data-emotion=""></style><style type="text/css">.dropdown-currencyNameWrapper{display:inline-block;line-height:1.3}.dropdown-currencyCode{display:block;font-size:2.4rem;font-weight:900;margin-bottom:-3px}.dropdown-currencyName{display:block;font-size:1.4rem;text-overflow:ellipsis;white-space:nowrap;overflow:hidden}.dropdown-arrowDown{height:20px;width:20px}.dropdown-arrowDown svg g{fill:#fff}</style><style type="text/css">.converterform-wrapper form{max-width:930px;display:-ms-flexbox;display:flex;-ms-flex-pack:center;justify-content:center;-ms-flex-align:end;align-items:flex-end;margin:0 auto;margin-bottom:15px}.converterform-field-wrap{width:270px;margin-right:10px}.converterform-field-wrap button{width:100%}.converterform-wrapper .converterform-dropdown .converterform-dropdown__control--is-focused,.converterform-wrapper button.converterform-inverseButton:focus{outline:0;box-shadow:0 0 0 2px #e86600}.converterform-wrapper .converterform-dropdown .converterform-dropdown__control{background-color:#fff;caret-color:#002272;color:#002272;cursor:pointer;border-width:0;height:60px;width:100%;border-radius:10px;overflow-y:hidden}.converterform-dropdown .dropdown-currencyNameWrapper{max-width:140px}.converterform-dropdown .converterform-dropdown__value-container object{height:40px;width:40px}.converterform-dropdown .converterform-dropdown__menu{border-radius:0 0 5px 5px;z-index:100}.converterform-dropdown__option.is-tablet{display:block}@media (max-width:900px){.converterform-wrapper{padding:0}.converterform-wrapper form{display:flex;justify-content:center;align-items:center;margin:0 auto;flex-wrap:wrap}.converterform-field-wrap.inputFieldWrap{margin-top:0}.converterform-field-wrap.open .converterform-dropdown__menu-list{max-height:100%}.converterform-field-wrap.open .converterform-dropdown__menu{position:fixed;top:59px;left:0;width:100vw;max-height:100%;text-align:left;margin:0;color:#000;border-radius:0;z-index:501}.converterform-field-wrap.open .converterform-dropdown__control{position:fixed;top:0;left:0;border-bottom:1px solid #001a6c}.converterform-field-wrap.open .converterform-dropdown .dropdown-currencyNameWrapper{max-width:80%}.converterform-field-wrap.open .converterform-dropdown__control{background-color:#fff;color:#000;margin:0;border-radius:0;width:100vw;height:60px;padding-right:0;z-index:501}.converterform-field-wrap.open .converterform-dropdown__control .converterform-dropdown__input{color:#000}.converterform-dropdown__menu{border-radius:0 0 5px 5px}.converterform-dropdown__menu .converterform-dropdown__menu-list{padding-top:0;border-radius:inherit}.converterform-dropdown .converterform-dropdown__menu #react-select-2-listbox.converterform-dropdown__menu-list{padding-bottom:0;padding-top:0}.converterform-dropdown__value-container{position:relative}}@media (max-width:900px){.converterform-wrapper.is-mobile{margin:0;padding:0}.converterform-wrapper .converterform-mobileForm{justify-content:space-between}.converterform-wrapper .converterform-mobileForm .converterform-mobileDropWrap{align-items:center;display:flex;justify-content:space-between;width:ca ...
# @-webkit-keyframes YI_OVERLAY_ANIMATION_fade-in{0%{opacity:0}100%{opacity:1}}@keyframes YI_OVERLAY_ANIMATION_fade-in{0%{opacity:0}100%{opacity:1}}
# @-webkit-keyframes YI_OVERLAY_ANIMATION_fade-in-right{0%{-webkit-transform:translateX(50px);transform:translateX(50px);opacity:0}100%{-webkit-transform:translateX(0);transform:translateX(0);opacity:1}}@keyframes YI_OVERLAY_ANIMATION_fade-in-right{0%{-webkit-transform:translateX(50px);transform:translateX(50px);opacity:0}100%{-webkit-transform:translateX(0);transform:translateX(0);opacity:1}}</style>
# </head>
# <body>
# <script type="text/javascript">
#                 var utag_data = {};
#             </script>
# <script type="text/javascript">
#                 (function(a,b,c,d){
#                 a='//tags.tiqcdn.com/utag/xe/main/prod/utag.js';
#                 b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
#                 a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#                 })();
#             </script><!-- WARNING: Automated extraction of rates is prohibited under the Terms of Use. -->
# <div id="reactContainer"><div class="bannerAdContainer Leaderboard-sc-1kwb0z8-2 jWZPGh"><div class="advertSlot AdContainer-sc-11qq4xy-0 eaLyzx" id="ad_12dd02a0_ddf9_11e9_8752_09e3d8948c83"><div align="center" id="tfasyncid_ad_12dd02a0_ddf9_11e9_8752_09e3d8948c83" name="tfasyncdiv"> <iframe allowtransparency="true" frameborder="0" height="90" hspace="0" id="tfasyncframe_4" marginheight="0" marginwidth="0" scrolling="no" vspace="0" width="728"></iframe></div></div></div><div class="gradient GradientStyled-h33oo2-0 fNbTFY"><div class="GuillocheContainer-sc-29mjq7-0 inwXnj"><div class="GuillocheStyled-sc-1oy3to0-0 iMCIB"><svg focusable="false" height="680px" opacity="0.06" space="preserve" style="width: 1900px;" version="1.1" viewbox="0 0 2060.640137 743.654663" width="1907px" x="0px" xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" y="0px"><g><g><lineargradient gradientunits="userSpaceOnUse" id="mainGuilloche_SVGID_1_" x1="96.091232" x2="1999.773071" y1="417.343323" y2="417.343323"><stop offset="0" stop-color="rgb(255,255,255)" stop-opacity="0"></stop><stop offset="1" stop-color="rgb(255,255,255)" stop-opacity="0.76"></stop></lineargradient><path class="st0" d="M1446.632446,624.590698c-64.069336,0.001953-129.210938-17.237305-197.398438-52.045898 c-79.487305-40.574219-154.904297-100.475586-227.83783-158.404297 c-71.418945-56.727051-145.242676-115.36377-220.352051-153.365723 c-39.015137-19.739761-75.413574-32.591324-111.276367-39.288589c-39.443848-7.365234-77.535156-7.180664-116.45166,0.563477 c-62.40332,12.419434-116.24707,37.599136-164.606445,76.977554c-44.245605,36.026367-80.509277,80.760742-115.57959,124.022461 c-34.089355,42.053711-69.32666,85.523438-112.078125,121.44043c-25.858398,21.725586-52.245605,38.864258-80.67041,52.393555 c-1.497559,0.711914-3.286133,0.076172-3.998535-1.419922c-0.711914-1.496094-0.076172-3.286133,1.419434-3.998047 c27.958496-13.307617,53.927246-30.175781,79.389648-51.569336c42.312012-35.547852,77.365234-78.791016,111.264648-120.609375 c35.274414-43.514648,71.737305-88.494141,116.464355-124.913086c49.136719-40.011246,103.836426-65.593765,167.224121-78.209 c39.680176-7.896973,78.514648-8.084961,118.724121-0.577148c36.429688,6.803711,73.354004,19.833008,112.883789,39.833008 c75.654297,38.277847,149.720703,97.107437,221.348572,154.000015 c72.729004,57.766602,147.907715,117.478516,226.86084,157.780273c92.027344,46.978516,178.345703,61.541992,263.889648,44.516602 c80.410156-16.00293,147.302734-46.851562,204.500977-94.308594c30.456055-25.268555,54.614258-52.594727,74.229492-75.993164 c6.402344-7.636719,10.15625-13.095703,13.787109-18.375c2.087891-3.036133,4.24707-6.175781,6.870117-9.673828 c50.739258-67.659668,88.938477-112.864258,113.537109-134.35791c21.030273-18.376465,42.879883-32.370132,66.797852-42.780289 c1.519531-0.661133,3.287109,0.035156,3.948242,1.553711c0.661133,1.519043-0.03418,3.286621-1.553711,3.948242 c-23.34375,10.160156-44.685547,23.832047-65.245117,41.796402c-24.283203,21.219238-62.196289,66.114258-112.683594,133.439453 c-2.549805,3.400391-4.579102,6.350586-6.727539,9.474609c-3.709961,5.395508-7.546875,10.973633-14.132812,18.830078 c-19.787109,23.603516-44.171875,51.180664-74.995117,76.754883c-57.985352,48.110352-125.749023,79.374023-207.161133,95.576172 C1493.644165,622.254761,1470.206665,624.589722,1446.632446,624.590698z" fill="url(#mainGuilloche_SVGID_1_)"></path><lineargradient gradientunits="userSpaceOnUse" id="mainGuilloche_SVGID_2_" x1="96.091156" x2="1069.958862" y1="403.635803" y2="403.635803"><stop offset="0" stop-color="rgb(255,255,255)" stop-opacity="0"></stop><stop offset="1" stop-color="rgb(255,255,255)" stop-opacity="0.76"></stop></lineargradient><path class="st1" d="M99.093933,597.175659c-1.121094,0-2.196777-0.631836-2.710938-1.711914 c-0.711914-1.496094-0.07666-3.286133,1.419434-3.998047c27.958496-13.307617,53.927246-30.175781,79.390137-51.569336 c42.311523-35.547852,77.364746-78.791016,111.26416-120.610352c35.274414-43.513672,71.737305-88.493164,116. ...
# <script>window.pageProps = {"fromCurrency":"USD","toCurrency":"SGD","amount":1,"isConverterResult":true,"isMobile":false,"isTablet":false,"locale":"en","isXemtSupported":false,"surveyUrl":"https:\/\/www.surveymonkey.com\/r\/S7YHH9J","forceSurveyOpenInNewTab":false};                var dynamicDataReq = new XMLHttpRequest();
#                 dynamicDataReq.addEventListener("load", function() {
#                     window.dynamicPageProps = null;
#                     if (this.readyState === XMLHttpRequest.DONE && this.status === 200) {
#                         var data = JSON.parse(this.responseText);
#                         window.dynamicPageProps = {
#                             dynamicData: data.payload,
#                             resourceStrings: data.resourceStrings
#                         };
#                         if (typeof renderPage !== "undefined") {
#                             renderPage();
#                         }
#                     }
#                 });
#
#                 dynamicDataReq.open("GET", "/api/page_resources/converter.php?fromCurrency=USD&toCurrency=SGD");
#                 dynamicDataReq.send();</script><script>
#     const unspeedyUserAgents = /(prerender|iPhone|iPad)/i;
#     const SC_DISABLE_SPEEDY = unspeedyUserAgents.test(navigator.userAgent);
# </script> <script>
#                 var isModernBrowser = (
#                     !!window.Promise &&
#                     !!Array.prototype.find &&
#                     !!window.Set &&
#                     !!Number.parseInt &&
#                     !!Number.parseFloat
#                 );
#
#                 if (!isModernBrowser) {
#                     var scriptElement = document.createElement('script');
#
#                     scriptElement.async = false;
#                     scriptElement.src = "https://www.xe.com/themes/xe/js/react/polyfills.6a3b5c720d8405b875ca.min.js";
#                     document.head.appendChild(scriptElement);
#                 }
#             </script><script src="https://www.xe.com/themes/xe/js/react/commons.56522407ae4d44372e2f.min.js"></script><script src="https://www.xe.com/themes/xe/js/react/converter.4a956b32dd13bd10d5a9.min.js"></script>
# <iframe height="1" id="utag_32_iframe" src="//8064740.fls.doubleclick.net/activityi;src=8064740;type=remar0;cat=xeland01;ord=1;num=3777918064465.9126?" style="display:none" width="1"></iframe><iframe class="aamIframeLoaded" id="destination_publishing_iframe_ria_0" name="destination_publishing_iframe_ria_0_name" sandbox="allow-scripts allow-same-origin" src="https://ria.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fwww.xe.com%2Fcurrencyconverter%2Fconvert%2F%3FAmount%3D1%26From%3DUSD%26To%3DSGD" style="display: none; width: 0px; height: 0px;" title="Adobe ID Syncing iFrame"></iframe><iframe name="yie-js" src="about:blank" style="display: none;"></iframe><iframe allow="autoplay" allowfullscreen="allowfullscreen" name="yie-sandbox-33df6d65-4c17-40d6-9f5a-bb314cb8e067" src="https://td.yieldify.com/0.0.1/tag/1.143.0/main.html" style="display: none;"></iframe></body></html>

# %%
pricetag = soup.find("span", {"class":"converterresult-toAmount"})
price = pricetag.text
#row = ()
#save_a_row_to_csv(row)
# Out:
# 1.37819
